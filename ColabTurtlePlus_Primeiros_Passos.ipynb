# %% [markdown]
# <a href="https://colab.research.google.com/github/vitor-laudares/pythonstellantis/blob/main/ColabTurtlePlus_Primeiros_Passos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Instalação da Biblioteca ColabTurtle

# %%
# !pip install -q ColabTurtlePlus

# %% [markdown]
# ### Configurações Iniciais

# %%
from ColabTurtlePlus.Turtle import *

# %% [markdown]
# ### Código Principal

# %%
clearscreen()
showborder()
t = Turtle()
t.shape('turtle2')
#Desafio 1
# setup(400, 400)
# t.penup()
# t.goto(-100, -100)
# t.pendown()
# for c in range(10):
#   t.left(90)
#   t.forward(20)
#   t.right(90)
#   t.forward(20)
# t.hideturtle()

#Desafio 2
# setup(350, 350)
# for c in range(8):
#   t.forward(150)
#   t.penup()
#   t.goto(0, 0)
#   t.pendown()
#   t.left(45)
# t.hideturtle()

#Desafio 3
setup(800, 200)
t.penup()
t.goto(-330, 0)
t.pendown()
for c in range(7):
  # Traço vertical
  t.penup()
  t.left(90)
  t.forward(40)
  t.pendown()
  t.back(80)
  t.penup()
  t.forward(40)
  #Traço horizontal
  t.right(90)
  t.back(40)
  t.pendown()
  t.forward(80)
  #Próxima posição
  if c < 6 :
    t.penup()
    t.forward(70)
    t.pendown()
t.hideturtle()
